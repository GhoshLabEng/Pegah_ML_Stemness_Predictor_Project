# %% [markdown]
# ### File processing

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
# csv_file = '/Users/pegaheizad/Desktop/Ghosh_lab/MyExpt_cells_filtered.csv'
# data = pd.read_csv(csv_file)

# Convert to Excel file
# excel_file = '/Users/pegaheizad/Desktop/Ghosh_lab/data_files_2/MyExpt_cells_filtered.xlsx'
# data.to_excel(excel_file, index=False)

# Read the Excel file
file_path = '/Users/pegaheizad/Desktop/Ghosh_lab/with_normalized_cd73_intensities/data_files/MyExpt_cells_filtered.xlsx'
df = pd.read_excel(file_path)

# Create a copy of the dataframe
# df_copy = df.copy()

# Add a new column "Normalized_Intensities"
# df_copy['Normalized_Intensities'] = df_copy['Intensity_MeanIntensity_cd73_img'] / df_copy['Intensity_MeanIntensity_dapi_img']

# Save the modified dataframe to a new Excel file
# output_file = '/Users/pegaheizad/Desktop/Ghosh_lab/data_files_2/MyExpt_cells_filtered_normalized.xlsx'
# df_copy.to_excel(output_file, index=False)

# print(f"New Excel file with 'Normalized_Intensities' column has been saved as {output_file}.")

# df = pd.read_excel('/Users/pegaheizad/Desktop/Ghosh_lab/data_files_2/MyExpt_cells_filtered_normalized.xlsx')

# %%
import pandas as pd

# Read the Excel file
file_path = '/Users/pegaheizad/Desktop/Ghosh_lab/data_files_2/MyExpt_cells_filtered.xlsx'
df = pd.read_excel(file_path)

# Create a copy of the dataframe
df_copy = df.copy()

average_dapi_intensity = df_copy['Intensity_MeanIntensity_dapi_img'].mean()

# Add a new column "Normalized_Intensities"
df_copy['Normalized_Intensities'] = df_copy['Intensity_MeanIntensity_cd73_img'] / average_dapi_intensity

# Save the modified dataframe to a new Excel file
output_file = '/Users/pegaheizad/Desktop/Ghosh_lab/data_files_2/MyExpt_cells_filtered_normalized_avg.xlsx'
df_copy.to_excel(output_file, index=False)
# Out:
# Exception ignored in: <function ZipFile.__del__ at 0x10606bd00>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/uqbio2024_py310/lib/python3.10/zipfile.py", line 1833, in __del__
#     self.close()
#   File "/opt/anaconda3/envs/uqbio2024_py310/lib/python3.10/zipfile.py", line 1850, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file

# %%
import matplotlib.pyplot as plt

# Plot the histogram of the specified column
plt.figure(figsize=(10, 6))
plt.xlim(left=0, right=0.2)
plt.hist(df['Intensity_MeanIntensity_cd73_img'].dropna(), bins=30, edgecolor='black')
plt.xlabel('Mean Intensity (Cell)')
plt.ylabel('Frequency')
plt.title('Histogram of Mean Intensity')
plt.grid(True)
plt.show()

# %% [markdown]
# ### TCP vs 527

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Separate data based on growing surface
tcp_data = df[df['Metadata_FileLocation'].str.contains('TCP', na=False)]['Intensity_MeanIntensity_cd73_img']
soft_data = df[df['Metadata_FileLocation'].str.contains('soft', na=False)]['Intensity_MeanIntensity_cd73_img']

# Create the overlayed histograms
plt.figure(figsize=(8, 6))
plt.xlim(left=0, right=0.2)
plt.hist(tcp_data, bins=30, alpha=0.5, label='TCP (Hard Surface)', color='blue')
plt.hist(soft_data, bins=30, alpha=0.5, label='Soft Surface', color='orange')

# Add titles and labels
plt.title('Histogram of Mean cd73 Intensity Across Growing Surfaces')
plt.xlabel('Mean cd73 Intensity')
plt.ylabel('Frequency')
plt.grid(True)
plt.legend(loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# ### P3 vs P5

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Separate data based on growing surface
p3_data = df[df['Metadata_FileLocation'].str.contains('P3', na=False)]['Intensity_MeanIntensity_cd73_img']
p5_data = df[df['Metadata_FileLocation'].str.contains('P5', na=False)]['Intensity_MeanIntensity_cd73_img']

# Create the overlayed histograms
plt.figure(figsize=(8, 6))
plt.xlim(left=0, right=0.2)
plt.hist(p3_data, bins=30, alpha=0.5, label='P3', color='blue')
plt.hist(p5_data, bins=30, alpha=0.5, label='P5', color='orange')

# Add titles and labels
plt.title('Histogram of Normalized Mean Intensity Across Passages')
plt.xlabel('Normalized Mean Intensity')
plt.ylabel('Frequency')
plt.grid(True)
plt.legend(loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# ### Comparing passages and growing surfaces

# %%
import matplotlib.pyplot as plt

# Separate data based on growing surface
p3TCP_data = df[df['Metadata_FileLocation'].str.contains('P3_TCP')]['Intensity_MeanIntensity_cd73_img']
p3soft_data = df[df['Metadata_FileLocation'].str.contains('P3_soft')]['Intensity_MeanIntensity_cd73_img']
p5TCP_data = df[df['Metadata_FileLocation'].str.contains('P5_TCP')]['Intensity_MeanIntensity_cd73_img']
p5soft_data = df[df['Metadata_FileLocation'].str.contains('P5_soft')]['Intensity_MeanIntensity_cd73_img']

# Create the overlayed histograms
plt.figure(figsize=(8, 6))
plt.hist(p3TCP_data, bins=30, alpha=0.5, label='P3 TCP', color='blue')
plt.hist(p3soft_data, bins=30, alpha=0.5, label='P3 soft', color='orange')
plt.hist(p5TCP_data, bins=30, alpha=0.5, label='P5 TCP', color='pink')
plt.hist(p5soft_data, bins=30, alpha=0.5, label='P5 soft', color='green')
plt.xlim(left=0, right=0.2)

# Add titles and labels
plt.title('Histogram of Normalized Mean Intensity Across Passages & Growing Surfaces')
plt.xlabel('Normalized Mean Intensity')
plt.ylabel('Frequency')
plt.grid(True)
plt.legend(loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# ### Control P3 vs 527

# %%
import matplotlib.pyplot as plt

# Separate data based on growing surface
p3TCP_data = normalized_df[normalized_df['Metadata_FileLocation'].str.contains('P3_TCP')]['Normalized_Intensities']
p3soft_data = normalized_df[normalized_df['Metadata_FileLocation'].str.contains('P3_soft')]['Normalized_Intensities']

# Create the overlayed histograms
plt.figure(figsize=(8, 6))
plt.hist(p3TCP_data, bins=30, alpha=0.5, label='P3 TCP', color='blue')
plt.hist(p3soft_data, bins=30, alpha=0.5, label='P3 soft', color='orange')
plt.xlim(left=0, right=10)

# Add titles and labels
plt.title('Histogram of Normalized Mean Intensity P3 control vs 527')
plt.xlabel('Normalized Mean Intensity')
plt.ylabel('Frequency')
plt.grid(True)
plt.legend(loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# ### Control P5 vs 527

# %%
import matplotlib.pyplot as plt

# Separate data based on growing surface
p5TCP_data = normalized_df[normalized_df['Metadata_FileLocation'].str.contains('P5_TCP')]['Normalized_Intensities']
p5soft_data = normalized_df[normalized_df['Metadata_FileLocation'].str.contains('P5_soft')]['Normalized_Intensities']

# Create the overlayed histograms
plt.figure(figsize=(8, 6))
plt.hist(p5TCP_data, bins=30, alpha=0.5, label='P5 TCP', color='blue')
plt.hist(p5soft_data, bins=30, alpha=0.5, label='P5 soft', color='orange')
plt.xlim(left=0, right=10)

# Add titles and labels
plt.title('Histogram of Normalized Mean Intensity P5 control vs 527')
plt.xlabel('Normalized Mean Intensity')
plt.ylabel('Frequency')
plt.grid(True)
plt.legend(loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# ## Individual stats for each of the 4 experimental conditions

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the excel file
file_path = '/Users/pegaheizad/Desktop/Ghosh_lab/data_files/cd73_data.xlsx'
df = pd.read_excel(file_path)

# Separate data based on P3 & growing surface
p3_data = df['Intensity_MeanIntensity_cells']

# Calculate the mean, median, and standard deviation
mean_p3_data = p3_data.mean()
median_p3_data = p3_data.median()
std_p3_data = p3_data.std()

# Print the results
print(f"Mean Intensity: {mean_p3_data}")
print(f"Median Intensity: {median_p3_data}")
print(f"Standard Deviation of Intensity: {std_p3_data}")
# Out:
# Mean Intensity: 0.016836649036307664
# Median Intensity: 0.008750427528578495
# Standard Deviation of Intensity: 0.018037649301195578

# %% [markdown]
# ### P3 soft

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the excel file
file_path = '/Users/pegaheizad/Desktop/Ghosh_lab/data_files/cd73_data.xlsx'
df = pd.read_excel(file_path)

# Separate data based on P3 & growing surface
p3soft_data = df[(df['Metadata_Passage'] == 3) & (df['Metadata_GrowingSurface'] == 'soft')]['Intensity_MeanIntensity_cells']

# Calculate the mean, median, and standard deviation
mean_p3soft_data = p3soft_data.mean()
median_p3soft_data = p3soft_data.median()
std_p3soft_data = p3soft_data.std()

# Print the results
print(f"Mean Intensity: {mean_p3soft_data}")
print(f"Median Intensity: {median_p3soft_data}")
print(f"Standard Deviation of Intensity: {std_p3soft_data}")
# Out:
# Mean Intensity: 0.025101036535043697
# Median Intensity: 0.02529402404160207
# Standard Deviation of Intensity: 0.014736917792508882

# %% [markdown]
# ### P3 TCP

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the excel file
file_path = '/Users/pegaheizad/Desktop/Ghosh_lab/data_files/cd73_data.xlsx'
df = pd.read_excel(file_path)

# Separate data based on P3 & growing surface
p3TCP_data = df[(df['Metadata_Passage'] == 3) & (df['Metadata_GrowingSurface'] == 'TCP')]['Intensity_MeanIntensity_cells']

# Calculate the mean, median, and standard deviation
mean_p3TCP = p3TCP_data.mean()
median_p3TCP = p3TCP_data.median()
std_p3TCP = p3TCP_data.std()

# Print the results
print(f"Mean Intensity: {mean_p3TCP}")
print(f"Median Intensity: {median_p3TCP}")
print(f"Standard Deviation of Intensity: {std_p3TCP}")
# Out:
# Mean Intensity: 0.025087379762314916
# Median Intensity: 0.02419951404352292
# Standard Deviation of Intensity: 0.018294850065300808

# %% [markdown]
# ### P5 soft

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the excel file
file_path = '/Users/pegaheizad/Desktop/Ghosh_lab/data_files/cd73_data.xlsx'
df = pd.read_excel(file_path)

# Separate data based on P3 & growing surface
p5soft_data = df[(df['Metadata_Passage'] == 5) & (df['Metadata_GrowingSurface'] == 'soft')]['Intensity_MeanIntensity_cells']

# Calculate the mean, median, and standard deviation
mean_p5soft_data = p5soft_data.mean()
median_p5soft_data = p5soft_data.median()
std_p5soft_data = p5soft_data.std()

# Print the results
print(f"Mean Intensity: {mean_p5soft_data}")
print(f"Median Intensity: {median_p5soft_data}")
print(f"Standard Deviation of Intensity: {std_p5soft_data}")
# Out:
# Mean Intensity: 0.00765772580779655
# Median Intensity: 0.006384156909830637
# Standard Deviation of Intensity: 0.011708139882486684

# %% [markdown]
# ### P5 TCP

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the excel file
file_path = '/Users/pegaheizad/Desktop/Ghosh_lab/data_files/cd73_data.xlsx'
df = pd.read_excel(file_path)

# Separate data based on P3 & growing surface
p5TCP_data = df[(df['Metadata_Passage'] == 3) & (df['Metadata_GrowingSurface'] == 'TCP')]['Intensity_MeanIntensity_cells']

# Calculate the mean, median, and standard deviation
mean_p5TCP = p5TCP_data.mean()
median_p5TCP = p5TCP_data.median()
std_p5TCP = p5TCP_data.std()

# Print the results
print(f"Mean Intensity: {mean_p5TCP}")
print(f"Median Intensity: {median_p5TCP}")
print(f"Standard Deviation of Intensity: {std_p5TCP}")
# Out:
# Mean Intensity: 0.025087379762314916
# Median Intensity: 0.02419951404352292
# Standard Deviation of Intensity: 0.018294850065300808
